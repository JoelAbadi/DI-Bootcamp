# %% [markdown]
# <a href="https://colab.research.google.com/github/JoelAbadi/DI-Bootcamp/blob/main/D2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exersice 1
#
# 1.   A company’s financial reports stored in an Excel file.	    -Structured
# 2.   Photographs uploaded to a social media platform.	          -Unstructured
# 3.   A collection of news articles on a website.	              -Unstructured
# 4.   Inventory data in a relational database.	                  -Structured
# 5.   Recorded interviews from a market research study.	        -Unstructured

# %% [markdown]
# Exercise 2
#
# | Unstructured Data                | Method to Structure                                                               | Reasoning                                                          |
# | -------------------------------- | --------------------------------------------------------------------------------- | ------------------------------------------------------------------ |
# | Blog posts about travel          | Use NLP to extract key topics, dates, locations, and structure them in a table.   | Turns free-form text into organized, searchable information.       |
# | Customer service call recordings | Use speech-to-text to transcribe, then analyze with NLP for intent and sentiment. | Makes the data analyzable and searchable.                          |
# | Handwritten notes                | OCR (Optical Character Recognition) followed by manual tagging.                   | Converts image text into digital, structured format.               |
# | Cooking video                    | Use video transcription, segment by steps or ingredients, store as JSON or CSV.   | Converts audio/visual content into step-by-step structured format. |

# %% [markdown]
# Exercise 3

# %%
from google.colab import files
uploaded = files.upload()  # You will upload "train.zip"
# Out:
#      <input type="file" id="files-48f25d06-54c3-4637-8e5b-0d756e3414eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-48f25d06-54c3-4637-8e5b-0d756e3414eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.listdir("/content")
# Out:
# ['.config',
#  '.ipynb_checkpoints',
#  'train (2).zip',
#  'train (1).zip',
#  'train.zip',
#  'W3',
#  'sample_data']

# %%
import zipfile
import pandas as pd

# Correct file path in Colab
zip_path = "/content/train.zip"

# Unzip
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("/content/")

# Load CSV
df = pd.read_csv("/content/train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Exercise 4

# %%
zip_path = "/content/Iris_dataset.zip"

# %%
zip_path = "/mnt/data/Iris_dataset.zip"

# %%
from google.colab import files
uploaded = files.upload()  # Upload your Iris_dataset.zip
# Out:
#      <input type="file" id="files-f5130b43-19d5-4b03-9f6e-d0bfb95d64e2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f5130b43-19d5-4b03-9f6e-d0bfb95d64e2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.listdir("/content")
# Out:
# ['.config',
#  '.ipynb_checkpoints',
#  'train (2).zip',
#  'train (1).zip',
#  'Iris_dataset.zip',
#  'train.zip',
#  'train.csv',
#  'W3',
#  'sample_data']

# %%
import zipfile
import pandas as pd

# Use the exact filename from previous step
zip_path = "/content/Iris_dataset.zip"

# Unzip the file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("/content/")

# List unzipped files
print(os.listdir("/content"))
# Out:
# ['.config', '.ipynb_checkpoints', 'train (2).zip', 'train (1).zip', 'Iris_dataset.zip', 'train.zip', 'Iris_dataset.csv', 'train.csv', 'W3', 'sample_data']

# %%
# Load CSV
df = pd.read_csv("/content/Iris_dataset.csv")
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %% [markdown]
# Exercise 5

# %%
import pandas as pd

# Create sample data
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Country': ['USA', 'UK', 'Canada']
}

df = pd.DataFrame(data)
df.head()
# Out:
#       Name  Age Country
# 0    Alice   25     USA
# 1      Bob   30      UK
# 2  Charlie   35  Canada

# %%
# !pip install openpyxl

# %%
# Export to Excel (without index)
df.to_excel("people.xlsx", index=False)

# %%
from google.colab import files
files.download("people.xlsx")

# %%
# Export to JSON
df.to_json("people.json", orient="records", indent=2)

# Download the file
files.download("people.json")

# %% [markdown]
# Exercise 6

# %%
from google.colab import files
uploaded = files.upload()  # Upload posts.zip again here
# Out:
#      <input type="file" id="files-134098a3-7519-44dd-a208-461d0d6cc8f3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-134098a3-7519-44dd-a208-461d0d6cc8f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os

# List files to confirm the correct name
print("Current files in /content:", os.listdir("/content"))

# Assuming it's called 'posts.zip' (adjust name if different)
zip_path = "/content/posts.zip"

# Extract contents
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("/content/")

# Show what got extracted
print("Extracted files:", os.listdir("/content"))
# Out:
# Current files in /content: ['.config', '.ipynb_checkpoints', 'people.xlsx', 'train (2).zip', 'train (1).zip', 'Iris_dataset.zip', 'train.zip', 'people.json', 'Iris_dataset.csv', 'posts.zip', 'train.csv', 'W3', 'sample_data']
# Extracted files: ['.config', '.ipynb_checkpoints', 'people.xlsx', 'train (2).zip', 'train (1).zip', 'Iris_dataset.zip', 'train.zip', 'people.json', 'Iris_dataset.csv', 'posts.json', 'posts.zip', 'train.csv', 'W3', 'sample_data']

# %%
import pandas as pd

# Load the JSON file (replace name if needed)
df = pd.read_json("/content/posts.json")
df.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...
